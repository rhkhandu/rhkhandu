# %% [markdown]
# <a href="https://colab.research.google.com/github/rhkhandu/rhkhandu/blob/main/First_in_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gdp_data = pd.read_csv('/content/drive/MyDrive/Data Set/gapminder_gdp_asia.csv')

# %%
world_dev_index = pd.read_excel('/content/drive/MyDrive/Data Set/Data_Extract_From_World_Development_Indicators.xlsx')

# %%
world_dev_index
# Out:
#                                         Country Name    Time  \
# 0                                         Bangladesh  2006.0
# 1                                         Bangladesh  2007.0
# 2                                         Bangladesh  2008.0
# 3                                         Bangladesh  2009.0
# 4                                         Bangladesh  2010.0
# ..                                               ...     ...
# 88                                               NaN     NaN
# 89                                               NaN     NaN
# 90                                               NaN     NaN
# 91  Data from database: World Development Indicators     NaN
# 92                          Last Updated: 10/07/2020     NaN
#
#     GDP per capita (constant 2010 US$)  CO2 emissions (metric tons per capita)
# 0                           649.929885                                0.309163
# ...

# %%
world_dev_index.head()
# Out:
#   Country Name    Time  GDP per capita (constant 2010 US$)  \
# 0   Bangladesh  2006.0                          649.929885
# 1   Bangladesh  2007.0                          687.323086
# 2   Bangladesh  2008.0                          720.357004
# 3   Bangladesh  2009.0                          748.296060
# 4   Bangladesh  2010.0                          781.153594
#
#    CO2 emissions (metric tons per capita)
# 0                                0.309163
# 1                                0.312206
# 2                                0.343895
# 3                                0.373297
# 4                                0.408084

# %%
world_dev_index.tail()
# Out:
#                                         Country Name  Time  \
# 88                                               NaN   NaN
# 89                                               NaN   NaN
# 90                                               NaN   NaN
# 91  Data from database: World Development Indicators   NaN
# 92                          Last Updated: 10/07/2020   NaN
#
#     GDP per capita (constant 2010 US$)  CO2 emissions (metric tons per capita)
# 88                                 NaN                                     NaN
# 89                                 NaN                                     NaN
# 90                                 NaN                                     NaN
# 91                                 NaN                                     NaN
# 92                                 NaN                                     NaN

# %%
world_dev_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 4 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country Name                            90 non-null     object
#  1   Time                                    88 non-null     float64
#  2   GDP per capita (constant 2010 US$)      88 non-null     float64
#  3   CO2 emissions (metric tons per capita)  88 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 3.0+ KB

# %%
gdp_data
# Out:
#                country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0          Afghanistan      779.445314      820.853030      853.100710
# 1              Bahrain     9867.084765    11635.799450    12753.275140
# 2           Bangladesh      684.244172      661.637458      686.341554
# 3             Cambodia      368.469286      434.038336      496.913648
# 4                China      400.448611      575.987001      487.674018
# 5      Hong Kong China     3054.421209     3629.076457     4692.648272
# 6                India      546.565749      590.061996      658.347151
# 7            Indonesia      749.681655      858.900271      849.289770
# 8                 Iran     3035.326002     3290.257643     4187.329802
# 9                 Iraq     4129.766056     6229.333562     8341.737815
# 10              Israel     4086.522128     5385.278451     7105.630706
# 11               Japan     3216.956347     4317.694365     6576.649461
# ...

# %%
gdp_data.head()
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0  Afghanistan      779.445314      820.853030      853.100710
# 1      Bahrain     9867.084765    11635.799450    12753.275140
# 2   Bangladesh      684.244172      661.637458      686.341554
# 3     Cambodia      368.469286      434.038336      496.913648
# 4        China      400.448611      575.987001      487.674018
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0      836.197138      739.981106      786.113360      978.011439
# 1    14804.672700    18268.658390    19340.101960    19211.147310
# 2      721.186086      630.233627      659.877232      676.981866
# 3      523.432314      421.624026      524.972183      624.475478
# 4      612.705693      676.900092      741.237470      962.421381
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0      852.395945      649.341395      635.341351      726.734055
# ...

# %%
gdp_data.tail()
# Out:
#                country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 28              Taiwan     1206.947913     1507.861290     1822.879028
# 29            Thailand      757.797418      793.577415     1002.199172
# 30             Vietnam      605.066492      676.285448      772.049160
# 31  West Bank and Gaza     1515.592329     1827.067742     2198.956312
# 32          Yemen Rep.      781.717576      804.830455      825.623201
#
#     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 28     2643.858681     4062.523897     5596.519826     7426.354774
# 29     1295.460660     1524.358936     1961.224635     2393.219781
# 30      637.123289      699.501644      713.537120      707.235786
# 31     2649.715007     3133.409277     3682.831494     4336.032082
# 32      862.442146     1265.047031     1829.765177     1977.557010
#
#     gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# ...

# %%
 gdp_data = pd.read_csv('/content/drive/MyDrive/Data Set/gapminder_gdp_asia.csv', index_col='country')

# %%
gdp_data
# Out:
#                     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Afghanistan             779.445314      820.853030      853.100710
# Bahrain                9867.084765    11635.799450    12753.275140
# Bangladesh              684.244172      661.637458      686.341554
# Cambodia                368.469286      434.038336      496.913648
# China                   400.448611      575.987001      487.674018
# Hong Kong China        3054.421209     3629.076457     4692.648272
# India                   546.565749      590.061996      658.347151
# Indonesia               749.681655      858.900271      849.289770
# Iran                   3035.326002     3290.257643     4187.329802
# Iraq                   4129.766056     6229.333562     8341.737815
# Israel                 4086.522128     5385.278451     7105.630706
# Japan                  3216.956347     4317.694365     6576.649461
# Jordan                 1546.907807     1886.080591     2348.009158
# ...

# %%
gdp_data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       33.000000       33.000000       33.000000       33.000000
# mean      5195.484004     5787.732940     5729.369625     5971.173374
# std      18634.890865    19506.515959    16415.857196    14062.591362
# min        331.000000      350.000000      388.000000      349.000000
# 25%        749.681655      793.577415      825.623201      836.197138
# 50%       1206.947913     1547.944844     1649.552153     2029.228142
# 75%       3035.326002     3290.257643     4187.329802     5906.731805
# max     108382.352900   113523.132900    95458.111760    80894.883260
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       33.000000       33.000000       33.000000       33.000000
# mean      8187.468699     7791.314020     7434.135157     7608.226508
# std      19087.502918    11815.777923     8701.176499     8090.262765
# ...

# %%
gdp_data.loc['Bangladesh']
# Out:
# gdpPercap_1952     684.244172
# gdpPercap_1957     661.637458
# gdpPercap_1962     686.341554
# gdpPercap_1967     721.186086
# gdpPercap_1972     630.233627
# gdpPercap_1977     659.877232
# gdpPercap_1982     676.981866
# gdpPercap_1987     751.979403
# gdpPercap_1992     837.810164
# gdpPercap_1997     972.770035
# gdpPercap_2002    1136.390430
# gdpPercap_2007    1391.253792
# Name: Bangladesh, dtype: float64

# %%
gdp_bd = gdp_data.loc['Bangladesh']

# %%
gdp_bd.describe()
# Out:
# count      12.000000
# mean      817.558818
# std       235.079648
# min       630.233627
# 25%       673.145764
# 50%       703.763820
# 75%       871.550132
# max      1391.253792
# Name: Bangladesh, dtype: float64

# %%
gdp_bd.round(decimals=2)
# Out:
# gdpPercap_1952     684.24
# gdpPercap_1957     661.64
# gdpPercap_1962     686.34
# gdpPercap_1967     721.19
# gdpPercap_1972     630.23
# gdpPercap_1977     659.88
# gdpPercap_1982     676.98
# gdpPercap_1987     751.98
# gdpPercap_1992     837.81
# gdpPercap_1997     972.77
# gdpPercap_2002    1136.39
# gdpPercap_2007    1391.25
# Name: Bangladesh, dtype: float64
